# %%
pip install FlowCal
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import FlowCal
import numpy as np
import matplotlib.pyplot as plt

# %%
s = FlowCal.io.FCSData('\\Users\Sigur\Desktop\FCS_Test_r1\S34012_r1.fcs')
s = FlowCal.transform.to_rfi(s)

# %%
fig = plt.figure()
FlowCal.plot.hist1d(s, channel='FL2-H', facecolor='#75d054', title='S34012_r1')
plt.xlim([0, 1000000])
plt.ylim([0, 5000])
import os
plt.show()
fig.savefig('\\Users\Sigur\Desktop\FCS_Test_r1\Histogram_S34012_r1.pdf')

# %%
FlowCal.plot.hist1d(s, channel='FL1-A', xscale='log', bins=1100)
plt.show()

# %%
import FlowCal

# Load FCS data
data = FlowCal.io.FCSData('\\Users\Sigur\Desktop\FCS_Test\S34012_r1.fcs')

# Print the available channels
print(data.channels)
# Out:
# ('TIME', 'FSC-A', 'FSC-H', 'FSC-W', 'SSC-A', 'SSC-H', 'SSC-W', 'FL1-A', 'FL1-H', 'FL1-W', 'FL2-A', 'FL2-H', 'FL2-W', 'FL3-A', 'FL3-H', 'FL3-W', 'FL4-A', 'FL4-H', 'FL4-W', 'FL5-A', 'FL5-H', 'FL5-W', 'FL6-A', 'FL6-H', 'FL6-W')

# %%
fig = plt.figure()
FlowCal.plot.hist1d(s, channel='FL2-H', facecolor='#21918c', title=S34012_r2)
import os
plt.show()
#fig.savefig('\\Users\Sigur\Desktop\FCS_Test_r1\Histogram_BS02034_2.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5332/3433511205.py in <module>
# ----> 1 fig = plt.figure()
#       2 FlowCal.plot.hist1d(s, channel='FL2-H', facecolor='#21918c', title=S34012_r2)
#       3 import os
#       4 plt.show()
#       5 #fig.savefig('\\Users\Sigur\Desktop\FCS_Test_r1\Histogram_BS02034_2.pdf')
#
# NameError: name 'plt' is not defined

# %%
FlowCal.plot.hist1d(s, channel='FL4-H', alpha=0.7, bins=128)
plt.legend(S34012_r1.fcs, loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6624/953044584.py in <module>
# ----> 1 FlowCal.plot.hist1d(s, channel='FL4-H', alpha=0.7, bins=128)
#       2 plt.legend(S34012_r1.fcs, loc='upper left')
#       3 plt.show()
#
# NameError: name 'FlowCal' is not defined

# %%
>>> FlowCal.plot.density2d(s, channels=['FSC-A', 'SSC-A'])
>>> plt.show()

# %%
>>> FlowCal.plot.density2d(s, channels=['SSC-A', 'FL1-A'], mode='scatter', cmap='viridis')
>>> plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6624/1256017589.py in <module>
# ----> 1 FlowCal.plot.density2d(s, channels=['SSC-A', 'FL1-A'], mode='scatter', cmap='viridis')
#       2 plt.show()
#
# NameError: name 'FlowCal' is not defined

# %%
fig = plt.figure()
FlowCal.plot.density2d(s, channels=['FSC-H', 'FL2-H'], mode='scatter', cmap='viridis', title='S34012_r1')
plt.xlim([5000, 1000000])
plt.ylim([-1000, 1000000])
import os
plt.show()
fig.savefig('\\Users\Sigur\Desktop\FCS_Test_r1\Scatter_S34012_r1.png', dpi=500)
